# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import glob
from glob import glob
import tensorflow as tf
import cv2
from keras import backend as K
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import matplotlib.pyplot as plt
import albumentations as alb
from albumentations import CenterCrop, RandomRotate90, GridDistortion, HorizontalFlip, VerticalFlip, ElasticTransform, Rotate, Transpose, ShiftScaleRotate, Flip

from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization
from tensorflow.keras.layers import UpSampling2D, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Recall, Precision

# %%
path = '/content/drive/MyDrive/VisãoComput/BowFire'

# %%
def load_data(path):
  #pega o caminho do conjunto de dados e fornece uma lista de imagens e caminhos de máscaras.
  images = sorted(glob(os.path.join(path, "images/*")))
  masks = sorted(glob(os.path.join(path, "masks/*"))) 
  return images, masks

# %%
def create_dir(path):
  #pega um caminho e cria um diretório vazio
  if not os.path.exists(path):
    os.makedirs(path)

# %%
def augment_data(images, masks, save_path, augment=True):
  H = 320
  W = 320

  for x, y in tqdm(zip(images, masks), total=len(images)):
    # percorre a lista de imagens e masks e o
    # o tqdm exibe o progresso do loop.
    name = x.split("/")[-1].split(".")
    'Extraindo o nome e extensão dos arquivos'
    image_name = name[0]
    image_extn = name[1]
    name = y.split("/")[-1].split(".")
    mask_name = name[0]
    mask_extn = name[1]

    'Lendo as imagens e as masks'
    x = cv2.imread(x, cv2.IMREAD_COLOR)
    y = cv2.imread(y, cv2.IMREAD_COLOR)

    'Definindo as técnicas de augmentation' # p = 1 é a probabilidade de aplicar o augment (ou seja, 100%)
    if augment == True:
      aug = ShiftScaleRotate(rotate_limit=60, p=1.0)
      augmented = aug(image=x, mask=y)
      x1 = augmented["image"]
      y1 = augmented["mask"]

      aug = RandomRotate90(p=1.0)
      augmented = aug(image=x, mask=y)
      x2 = augmented['image']
      y2 = augmented['mask']

      aug = GridDistortion(p=1.0)
      augmented = aug(image=x, mask=y)
      x3 = augmented['image']
      y3 = augmented['mask']

      aug = HorizontalFlip(p=1.0)
      augmented = aug(image=x, mask=y)
      x4 = augmented['image']
      y4 = augmented['mask']

      aug = VerticalFlip(p=1.0)
      augmented = aug(image=x, mask=y)
      x5 = augmented['image']
      y5 = augmented['mask']

      aug = ElasticTransform(p=1.0)
      augmented = aug(image=x, mask=y)
      x6 = augmented['image']
      y6 = augmented['mask']

      aug = Rotate(limit=45, p= 1.0)
      augmented = aug(image=x, mask=y)
      x7 = augmented['image']
      y7 = augmented['mask']

      aug = Transpose(p= 1.0)
      augmented = aug(image=x, mask=y)
      x8 = augmented['image']
      y8 = augmented['mask']

      aug = Rotate(limit=60, p= 1.0)
      augmented = aug(image=x, mask=y)
      x9 = augmented['image']
      y9 = augmented['mask']

      save_images = [x, x1, x2, x3, x4, x5, x6, x7, x8, x9]
      save_masks =  [y, y1, y2, y3, y4, y5, y6, y7, y8, y9] # salvando imagens e masks originais e geradas

      idx = 0
      for i, m in zip(save_images, save_masks):
        # percorrendo o vetor que armazena as imagens e masks
        i = cv2.resize(i, (W, H))             # redimensionando para o tamanho desejado e setado anteriormente
        m = cv2.resize(m, (W, H))

        if len(images) == 1:
          img_name = f"{image_name}.{image_extn}"  #nomeia as imagens e masks com nome e formato
          msk_name = f"{mask_name}.{mask_extn}"

        else:
          img_name = f"{image_name}_{idx}.{image_extn}"
          msk_name = f"{mask_name}_{idx}.{mask_extn}"

          image_path = os.path.join(save_path, "images/", img_name)  
          mask_path = os.path.join(save_path, "masks/", msk_name) #salva as imagens e masks 

          cv2.imwrite(image_path, i)  #indica o caminho que vai salvar
          cv2.imwrite(mask_path, m)

          idx += 1

# %%
image, mask = load_data(path) # apenas verificando e confirmando a quantidade 
print(f"Quantidade de Imagens: {len(image)} - Quantidade de Masks: {len(mask)}")
# Out:
# Quantidade de Imagens: 119 - Quantidade de Masks: 119

# %%
create_dir("new_dataFIRE/images")
create_dir("new_dataFIRE/masks") #criando as pastas que vão salvar os dados aumentados

# %%
augment_data(image, mask, "new_dataFIRE", augment=True) # aplica a função augment_data definida
# Out:
# 100%|██████████| 119/119 [03:59<00:00,  2.02s/it]

# %%
images, masks = load_data("new_dataFIRE/")
print('Nº de Imagens após augmentation: ', len(images))
print('Nº de Masks após augmentation: ', len(masks)) # carregando os dados aumentados e verificando a quantidade
# Out:
# Nº de Imagens após augmentation:  1190
# Nº de Masks após augmentation:  1190

# %%
path = "/content/new_dataFIRE"

# %%
np.random.seed(42)
tf.random.set_seed(42)

im_size = 320
batch_size = 8

# %%
def load_data(path, split=0.1): #pega o caminho, carrega imagens e masks e divide em treino, val e teste (70%, 15%, 15%)
    images = sorted(glob(os.path.join(path, "images/*")))
    masks = sorted(glob(os.path.join(path, "masks/*")))

    total_size = len(images)
    valid_size = int(split*total_size)
    test_size = int(split*total_size)

    X_train, X_val = train_test_split(images, test_size=valid_size, random_state=42)
    y_train, y_val = train_test_split(masks, test_size=valid_size, random_state=42)

    X_train, X_test = train_test_split(X_train, test_size=test_size, random_state=42)
    y_train, y_test = train_test_split(y_train, test_size=test_size, random_state=42)

    return (X_train,y_train), (X_val,y_val), (X_test,y_test)

# %%
def read_image(path):
  path = path.decode()
  x = cv2.imread(path, cv2.IMREAD_COLOR)
  #x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
  x = cv2.resize(x, (320,320))
  x = x/255
  return x

def read_mask(path):
  path = path.decode()
  x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
  x = cv2.resize(x, (320,320))
  x = x/255
  x = np.expand_dims(x, axis=-1) # para deixar no formato (H, W, 1)
  return x


  # aqui as duas funções carregam a imagem do caminho fornecido, redimensiona pra 224x224, normaliza os pixels
# dividindo por 255 e no fim retorna uma imagem colorida e a mask em preto e branco

# %%
def tf_parse(x, y):
  def _parse(x, y):
    x = read_image(x)
    y = read_mask(y)
    return x, y

  x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
  x.set_shape([320,320, 3])
  y.set_shape([320,320, 1])
  return x, y

def tf_dataset(x, y, batch):
  dataset = tf.data.Dataset.from_tensor_slices((x, y))
  dataset = dataset.map(tf_parse)
  dataset = dataset.batch(batch)
  dataset = dataset.repeat()
  return dataset

# aqui é construído um pipeline de dados, a primeira função analisa uma única imagem e caminho da mask
# a segunda função cria um pipeline tf.data que obtém uma lista de imagens, o caminho das masks e o batch.

# %%
(X_train,y_train), (X_val,y_val), (X_test,y_test) = load_data(path)  # Verificando os 80% treino e 20% pra valid e teste

print("Dados de treinamento: ", len(X_train))
print("Dados de validação: ", len(X_val))
print("Dados de teste: ", len(X_test))
# Out:
# Dados de treinamento:  952
# Dados de validação:  119
# Dados de teste:  119

# %%
X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

X_val = np.asarray(X_val)
y_val = np.asarray(y_val)

X_test = np.asarray(X_test)
y_test = np.asarray(y_test)

# %%
dados_treino = tf_dataset(X_train, y_train, batch = batch_size)
print(dados_treino)

dados_val = tf_dataset(X_val,y_val, batch = batch_size)
print(dados_val)

dados_test = tf_dataset(X_test,y_test, batch = batch_size)
print(dados_test)
# Out:
# <RepeatDataset shapes: ((None, 320, 320, 3), (None, 320, 320, 1)), types: (tf.float64, tf.float64)>
# <RepeatDataset shapes: ((None, 320, 320, 3), (None, 320, 320, 1)), types: (tf.float64, tf.float64)>
# <RepeatDataset shapes: ((None, 320, 320, 3), (None, 320, 320, 1)), types: (tf.float64, tf.float64)>

# %%
smooth = 1e-12
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def IoU(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection 
    x = (intersection + smooth) / (union + smooth)
    return x

# %%
metrics = [dice_coef, IoU]
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3,min_delta=0.0001,min_lr=0.00001),
    EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=False),
    tf.keras.callbacks.TensorBoard()
]

# %%
# Construindo o modelo
inputs = tf.keras.layers.Input((320,320,3))

# Contraction/Encoder path
c1 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
#kernel_initializer é pra definir os valores iniciais dos pesos q serão atualizados, pois precisa começar de algum lugar
#padding = same é pra garantir a imagem de saída tenha as mesmas dimensões da imagem de entrada

# c1 = tf.keras.layers.Dropout(0.1)(c1) #elimina alguns valores inuteis entre as camadas pra evitar overfitting
c1 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
#c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

c3 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
# c3 = tf.keras.layers.Dropout(0.1)(c3)
c3 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

c4 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
#c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

c5 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
# c5 = tf.keras.layers.Dropout(0.1)(c5)
c5 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

# Expansive/Decoder path
u6 = tf.keras.layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
#c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

u7 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
# c7 = tf.keras.layers.Dropout(0.1)(c7)
c7 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

u8 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
#c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

u9 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
# c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)
#outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(outputs)

model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), loss= dice_loss, metrics= metrics)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 320, 320, 3) 0
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 320, 320, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 320, 320, 32) 9248        conv2d_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 160, 160, 32) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 160, 160, 64) 18496       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 160, 160, 64) 36928       conv2d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 80, 80, 64)   0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 80, 80, 128)  73856       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 80, 80, 128)  147584      conv2d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 40, 40, 128)  0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 40, 40, 256)  295168      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 40, 40, 256)  590080      conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 20, 20, 256)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 20, 20, 512)  1180160     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 20, 20, 512)  2359808     conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 40, 40, 256)  524544      conv2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 40, 40, 512)  0           conv2d_transpose_8[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 40, 40, 256)  1179904     concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 40, 40, 256)  590080      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 80, 80, 128)  131200      conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 80, 80, 256)  0           conv2d_transpose_9[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 80, 80, 128)  295040      concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 80, 80, 128)  147584      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 160, 160, 64) 32832       conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 160, 160, 128 0           conv2d_transpose_10[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 160, 160, 64) 73792       concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 160, 160, 64) 36928       conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 320, 320, 32) 8224        conv2d_53[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 320, 320, 64) 0           conv2d_transpose_11[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 320, 320, 32) 18464       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 320, 320, 32) 9248        conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 320, 320, 1)  33          conv2d_55[0][0]
# ==================================================================================================
# Total params: 7,760,097
# Trainable params: 7,760,097
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Epoch 29/35
# 119/119 [==============================] - 29s 248ms/step - loss: 0.0623 - dice_coef: 0.9377 - IoU: 0.8829 - val_loss: 0.0916 - val_dice_coef: 0.9086 - val_IoU: 0.8332
# Epoch 30/35
# 119/119 [==============================] - 29s 248ms/step - loss: 0.0615 - dice_coef: 0.9385 - IoU: 0.8844 - val_loss: 0.0912 - val_dice_coef: 0.9089 - val_IoU: 0.8338
# Epoch 31/35
# 119/119 [==============================] - 30s 248ms/step - loss: 0.0607 - dice_coef: 0.9393 - IoU: 0.8858 - val_loss: 0.0909 - val_dice_coef: 0.9092 - val_IoU: 0.8344
# Epoch 32/35
# 119/119 [==============================] - 30s 248ms/step - loss: 0.0599 - dice_coef: 0.9401 - IoU: 0.8872 - val_loss: 0.0906 - val_dice_coef: 0.9095 - val_IoU: 0.8348
# Epoch 33/35
# 119/119 [==============================] - 30s 248ms/step - loss: 0.0592 - dice_coef: 0.9408 - IoU: 0.8885 - val_loss: 0.0903 - val_dice_coef: 0.9098 - val_IoU: 0.8354
# Epoch 34/35
# 119/119 [==============================] - 30s 248ms/step - loss: 0.0585 - dice_coef: 0.9415 - IoU: 0.8897 - val_loss: 0.0901 - val_dice_coef: 0.9100 - val_IoU: 0.8357
# Epoch 35/35
# 119/119 [==============================] - 29s 248ms/step - loss: 0.0578 - dice_coef: 0.9422 - IoU: 0.8910 - val_loss: 0.0899 - val_dice_coef: 0.9103 - val_IoU: 0.8361

# %%
import matplotlib.pyplot as plt
loss = results.history['loss']
val_loss = results.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs,loss,'y',label='Training Loss')
plt.plot(epochs,val_loss,'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
dic = results.history['dice_coef']
val_dic = results.history['val_dice_coef']
epochs = range(1, len(dic)+1)
plt.plot(epochs,dic,'y',label='Training Dice')
plt.plot(epochs,val_dic,'r',label='Validation Dice')
plt.title('Training and Validation Dice')
plt.xlabel('Epochs')
plt.ylabel('Dice')
plt.legend()
plt.show()

# %%
iou = results.history['IoU']
val_iou = results.history['val_IoU']
epochs = range(1, len(iou)+1)
plt.plot(epochs,iou,'y',label='Training IoU')
plt.plot(epochs,val_iou,'r',label='Validation IoU')
plt.title('Training and Validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

# %%
# rec = results.history['recall']
# val_rec = results.history['val_recall']
# epochs3 = range(1, len(rec)+1)
# plt.plot(epochs3,rec,'b',label='Recall de Treino')
# plt.plot(epochs3,val_rec,'r',label='Recall de Validação')
# plt.title('Recall de Treino e Validação')
# plt.xlabel('Época')
# plt.ylabel('Recall')
# plt.legend()
# plt.show()

# %%
# prec = results.history['precision']
# val_prec = results.history['val_precision']
# epochs4 = range(1, len(prec)+1)
# plt.plot(epochs4,prec,'b',label='Precision de Treino')
# plt.plot(epochs4,val_prec,'r',label='Precision de Validação')
# plt.title('Precision de Treino e Validação')
# plt.xlabel('Época')
# plt.ylabel('Precision')
# plt.legend()
# plt.show()

# %%
print('Coeficiente Dice de Treino:', model.evaluate(dados_treino, batch_size = batch_size, steps = train_steps)[1])
print('Coeficiente Dice de Validação:', model.evaluate(dados_val, batch_size = batch_size, steps = valid_steps)[1])
# Out:
# 119/119 [==============================] - 9s 77ms/step - loss: 0.0565 - dice_coef: 0.9435 - IoU: 0.8933
# Coeficiente Dice de Treino: 0.9435306787490845
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0899 - dice_coef: 0.9103 - IoU: 0.8361
# Coeficiente Dice de Validação: 0.9102694988250732

# %%
print('IoU de Treino:', model.evaluate(dados_treino, batch_size = 16, steps = train_steps)[2])
print('IoU de Validação:', model.evaluate(dados_val, batch_size = 16, steps = valid_steps)[2])
# Out:
# 119/119 [==============================] - 10s 80ms/step - loss: 0.0565 - dice_coef: 0.9435 - IoU: 0.8933
# IoU de Treino: 0.8933248519897461
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0899 - dice_coef: 0.9103 - IoU: 0.8361
# IoU de Validação: 0.8360815048217773

# %%
print('Coeficiente Dice de Teste:', model.evaluate(dados_test, batch_size = batch_size, steps = test_steps)[1])
print('IoU de Teste:', model.evaluate(dados_test, batch_size = batch_size, steps = test_steps)[2])
# Out:
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0887 - dice_coef: 0.9115 - IoU: 0.8389
# Coeficiente Dice de Teste: 0.9114658832550049
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0887 - dice_coef: 0.9115 - IoU: 0.8389
# IoU de Teste: 0.8389288783073425

# %%
def create_mask(pred_mask):
  pred_mask = tf.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[0]

# %%
def read_img(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    #x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (320,320))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (320,320))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
# PREDIÇÕES COM AUMENTO DE DADOS
for i, (x, y) in enumerate(zip(X_test[:15], y_test[:15])):
    x = read_img(x)
    y = read_mask(y)
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.1
    #y_pred = y_pred[0] > 0.5
    h, w, _ = x.shape
    # white_line = np.ones((h, 10, 3)) 

    all_images = [
        x,
        mask_parse(y),
        mask_parse(y_pred)
    ]
    image = np.concatenate(all_images, axis=1)
  
    fig = plt.figure(figsize=(12, 12))
    a = fig.add_subplot(1, 1, 1)
    imgplot = plt.imshow(image, 'gray')
